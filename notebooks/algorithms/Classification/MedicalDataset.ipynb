# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier


df=pd.read_csv('C:/Users/USER/Documents/Github/Machine Learning/datasets/Multiclass_Diabetes_Dataset.csv')
df.head()
# Out:
#    Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI  Class
# 0       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0      0
# 1       1   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0      0
# 2       1   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0      0
# 3       0   45   2.3  24    4.0   2.9  1.0  1.0  1.5   0.4  21.0      0
# 4       0   50   2.0  50    4.0   3.6  1.3  0.9  2.1   0.6  24.0      0

# %%
df['Class'].unique()
# Out:
# array([0, 1, 2])

# %%
df.isnull().sum()
# Out:
# Gender    0
# AGE       0
# Urea      0
# Cr        0
# HbA1c     0
# Chol      0
# TG        0
# HDL       0
# LDL       0
# VLDL      0
# BMI       0
# Class     0
# dtype: int64

# %%
X=df.drop(["Class"],axis=1)
y=df["Class"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=12,test_size=0.2)

from scipy.stats import randint
param_grid={
    'n_estimators':randint(50,100),
    'max_depth':[None,5,10,20],
    'max_features':['log2','sqrt']
}

# %%
model=RandomForestClassifier()
rand=RandomizedSearchCV(model,param_grid,cv=5)
rand.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                    param_distributions={'max_depth': [None, 5, 10, 20],
#                                         'max_features': ['log2', 'sqrt'],
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001D10D21D6A0>})

# %%
y_pred=rand.predict(X_test)

print("Best parameters: ",format(rand.best_params_))
print("Best Score: ",rand.best_score_)
# Out:
# Best parameters:  {'max_depth': 5, 'max_features': 'log2', 'n_estimators': 63}
# Best Score:  0.9857142857142858

# %%
from sklearn.metrics import classification_report

print("Classification report :\n",classification_report(y_pred,y_test))
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93        23
#            1       0.71      1.00      0.83         5
#            2       0.92      0.96      0.94        25
#
#     accuracy                           0.92        53
#    macro avg       0.88      0.94      0.90        53
# weighted avg       0.94      0.92      0.93        53
